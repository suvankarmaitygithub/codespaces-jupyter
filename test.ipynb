# %%
import pandas as pd
import numpy as np

# %%
a = 2
b = 10

# %%
import sklearn

# %%
import transformers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import transformers
#
# ModuleNotFoundError: No module named 'transformers'

# %%
import statistics

# %%
df = pd.read_excel("EPS_Dataset.xlsx")
df
# Out:
#               Bank name  Year  ROCE (%)  CASA (%)  Net Profit Margin (%)  \
# 0                   BoB  2023      1.91     39.47                  15.74
# 1                   BoB  2022      1.81     41.45                  10.40
# 2                   BoB  2021      1.85     40.15                   1.17
# 3                   BoB  2020      1.77     35.28                   0.71
# 4                   BoB  2019      1.78     35.03                   0.87
# 5                   SBI  2023      1.59     42.66                  15.12
# 6                   SBI  2022      1.42     44.51                  11.49
# 7                   SBI  2021      1.64     45.39                   7.69
# 8                   SBI  2020      1.79     44.22                   5.63
# 9                   SBI  2019      3.35     45.74                   0.35
# 10                  PNB  2023      1.57     41.99                   2.94
# 11                  PNB  2022      1.61     46.55                   4.61
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 1.4 MB/s eta 0:00:0000:0100:01
# ...
